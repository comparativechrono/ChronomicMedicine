# %% [markdown]
# <a href="https://colab.research.google.com/github/comparativechrono/ChronomicMedicine/blob/main/examples/cancer_cronodosing_1972.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# R can be a calculator

# %%
install.packages("tidyverse")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library("tidyverse")
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.8
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
x <- read_tsv("dosing_cancer.txt")
# Out:
# Rows: 16 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): Regime
# dbl (2): Time, Dose(mg/kg)
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
x
# Out:
#    Time Regime Dose(mg/kg)
# 1   2   S       7.5
# 2   5   S      15.0
# 3   8   S      30.0
# 4  11   S      67.5
# 5  14   S      67.5
# 6  17   S      30.0
# 7  20   S      15.0
# 8  23   S       7.5
# 9   2   R      30.0
# 10  5   R      30.0
# 11  8   R      30.0
# 12 11   R      30.0
# 13 14   R      30.0
# 14 17   R      30.0
# 15 20   R      30.0
# 16 23   R      30.0

# %%
x %>% ggplot(aes(x=Time, y=`Dose(mg/kg)`, colour = Regime)) +
geom_smooth(se = FALSE, size = 2) +
theme(text = element_text(size = 30))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
